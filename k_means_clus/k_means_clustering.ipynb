# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data={"height":[185,179,168,179,192,188,180,180,183,180,180,177],
      "weight":[72,56,60,68,72,77,71,70,84,88,67,76]}

# %%
initial_centroid=np.array([
    [185,72],
    [176,56]
])

# %%
kmesns=KMeans(
    n_clusters=2,
    init=initial_centroid,
    n_init=1,
    random_state=42
)

# %%
KMeans.fit(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 KMeans.fit(df)
#
# File c:\Users\Abhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1393, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1388 partial_fit_and_fitted = (
#    1389     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1390 )
#    1392 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
#    1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Abhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
# ...

# %%
KMeans(init=array([[185,72],
                   [170,56]]),n_clusters=)

# %%
df=pd.DataFrame(data)
df
# Out:
#     height  weight
# 0      185      72
# 1      179      56
# 2      168      60
# 3      179      68
# 4      192      72
# 5      188      77
# 6      180      71
# 7      180      70
# 8      183      84
# 9      180      88
# 10     180      67
# 11     177      76

# %%
df
# Out:
#     height  weight
# 0      185      72
# 1      179      56
# 2      168      60
# 3      179      68
# 4      192      72
# 5      188      77
# 6      180      71
# 7      180      70
# 8      183      84
# 9      180      88
# 10     180      67
# 11     177      76

# %%
df.shape
# Out:
# (12, 2)
